# %%
#Name: Sisham Maharjan
#Student ID: 2409266


#Using this function f(x)=x**2 - x - 1
 # Root Finding Method
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt


def plot_function(func, a, b):
    x = np.linspace(a, b, 400)

    y = func(x)
    plt.plot(x, y)
    plt.xlabel('x')
    plt.ylabel('f(x)')
    plt.title('Graph of the function')
    plt.grid(True)
    plt.show()


def newton_method(func, grad, x0, tol=1e-6, max_iter=100):
    # Main Loop starts here
    iter_count = 1
    while iter_count <= max_iter:
        if np.abs(grad(x0)) <= 1E-12:
            print("Mathematical Error! Found root may not be correct.")
            return x0
        x1 = x0 - func(x0) / grad(x0)  # new approximation of root
        x0 = x1
        if np.abs(func(x0)) <= tol:  # solution found
            return x0
        iter_count += 1

    print("Warning! Method exceeded maximum number of iterations.")
    return x0

# Main Driver Function:


if __name__ == "__main__":
    # Define the 1st Function for which the root is to be found
    func = lambda x: x**2 - x - 1
    # Define the gradient of the Function
    grad = lambda x: 2*x - 1

    # Call plot_function to plot graph of the function
    plot_function(func, -2, 2)

    x0 = 0  # Initial guess for 1st root
    # Call the Newton's method for 1st root
    our_root_1 = newton_method(func, grad, x0)



    # Call SciPy method (reference method) for 1st root
    sp_result_1 = sp.optimize.root(func, x0)
    sp_root_1 = sp_result_1.x.item()

    # Call the Newton's method for 2nd root
    x0 = 2  # Initial guess for 2nd root
    our_root_2 = newton_method(func, grad, x0)

    # Call SciPy method (reference method) for 2nd root
    sp_result_2 = sp.optimize.root(func, x0)
    sp_root_2 = sp_result_2.x.item()

    # Print the result
    print("1st root found by Newton's Method = {:0.8f}.".format(our_root_1))
    print("1st root found by SciPy = {:0.8f}".format(sp_root_1))

    print("2nd root found by Newton's Method = {:0.8f}.".format(our_root_2))
    print("2nd root found by SciPy = {:0.8f}".format(sp_root_2))

#Using this function f(x)=x**3 - x**2 - 2*x + 1
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt

def plot_function(func, a, b):
    x = np.linspace(a, b, 400)
    y = func(x)
    plt.plot(x, y)
    plt.xlabel('x')
    plt.ylabel('f(x)')
    plt.title('Graph of the function')
    plt.grid(True)
    plt.show()

def newton_method(func, grad, x0, tol=1e-6, max_iter=100):
    # Main Loop starts here
    iter_count = 1
    while iter_count <= max_iter:
        if np.abs(grad(x0)) <= 1E-12:
            print("Mathematical Error! Found root may not be correct.")
            return x0
        x1 = x0 - func(x0) / grad(x0)  # new approximation of root
        x0 = x1
        if np.abs(func(x0)) <= tol:  # solution found
            return x0
        iter_count += 1

    print("Warning! Method exceeded maximum number of iterations.")
    return x0


# Main Driver Function:
if __name__ == "__main__":
    # Define the Function for which the roots are to be found
    func = lambda x: x**3 - x**2 - 2*x + 1
    # Define the gradient of the Function
    grad = lambda x: 3*x**2 - 2*x - 2

    # Call plot_function to plot graph of the function
    plot_function(func, -2, 2)

    # Initial guess for 1st root
    x0_1 = -2
    # Call the Newton's method for 1st root
    our_root_1 = newton_method(func, grad, x0_1)

    # Initial guess for 2nd root
    x0_2 = 0
    # Call the Newton's method for 2nd root
    our_root_2 = newton_method(func, grad, x0_2)

    # Initial guess for 3rd root
    x0_3 = 2
    # Call the Newton's method for 3rd root
    our_root_3 = newton_method(func, grad, x0_3)

    # Call SciPy method (reference method) for roots
    sp_result_1 = sp.optimize.root(func, x0_1)
    sp_root_1 = sp_result_1.x.item()
    sp_result_2 = sp.optimize.root(func, x0_2)
    sp_root_2 = sp_result_2.x.item()
    sp_result_3 = sp.optimize.root(func, x0_3)
    sp_root_3 = sp_result_3.x.item()


    # Print the results
    print("1st root found by Newton's Method = {:.8f}.".format(our_root_1))
    print("1st root found by SciPy = {:.8f}".format(sp_root_1))

    print("2nd root found by Newton's Method = {:.8f}.".format(our_root_2))
    print("2nd root found by SciPy = {:.8f}".format(sp_root_2))

    print("3rd root found by Newton's Method = {:.8f}.".format(our_root_3))
    print("3rd root found by SciPy = {:.8f}".format(sp_root_3))
# Out:
# 1st root found by Newton's Method = -0.61803399.
# 1st root found by SciPy = -0.61803399
# 2nd root found by Newton's Method = 1.61803399.
# 2nd root found by SciPy = 1.61803399
# 1st root found by Newton's Method = -1.24697960.
# 1st root found by SciPy = -1.24697960
# 2nd root found by Newton's Method = 0.44504182.
# 2nd root found by SciPy = 0.44504187
# 3rd root found by Newton's Method = 1.80193774.
# 3rd root found by SciPy = 1.80193774

# %% [markdown]
# Plotting the Function
